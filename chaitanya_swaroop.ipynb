# %%
# Importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats

# %%
import warnings
warnings.filterwarnings("ignore")
import plotly.express as py
import plotly.graph_objects as gob
import datetime

# %%
# Improvising the Rows & Columns 

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', None)

# %%
# Importing the provided dataset

loan_df = pd.read_csv('loan.csv')
loan_df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade                 emp_title emp_length home_ownership  annual_inc verification_status issue_d  loan_status pymnt_plan                                                url                                               desc         purpose                 title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code application_type  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# ...

# %%
loan_df.shape
# Out:
# (39717, 111)

# %%
# Information of datatypes present in the dataset

loan_df.info(max_cols=150)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 111 columns):
# id                                39717 non-null int64
# member_id                         39717 non-null int64
# loan_amnt                         39717 non-null int64
# funded_amnt                       39717 non-null int64
# funded_amnt_inv                   39717 non-null float64
# term                              39717 non-null object
# int_rate                          39717 non-null object
# installment                       39717 non-null float64
# grade                             39717 non-null object
# sub_grade                         39717 non-null object
# emp_title                         37258 non-null object
# emp_length                        38642 non-null object
# home_ownership                    39717 non-null object
# annual_inc                        39717 non-null float64
# verification_status               39717 non-null object
# ...

# %%
# Analyzing the data of first and last 150

loan_df.head(150)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade                                 emp_title emp_length home_ownership  annual_inc verification_status issue_d  loan_status pymnt_plan                                                url                                               desc             purpose                                   title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code application_type  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# ...

# %%
loan_df.tail(150)
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade                                       emp_title emp_length home_ownership  annual_inc verification_status issue_d  loan_status pymnt_plan                                                url                                               desc             purpose                                     title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee   recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code application_type  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  \
# ...

# %%
loan_df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  funded_amnt_inv   installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  mths_since_last_delinq  mths_since_last_record      open_acc       pub_rec      revol_bal     total_acc     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# ...

# %%
# Finding out the null values in the variables (Data Cleaning - step - 1)

loan_df.isnull().sum()
# Out:
# id                                    0
# member_id                             0
# loan_amnt                             0
# funded_amnt                           0
# funded_amnt_inv                       0
# term                                  0
# int_rate                              0
# installment                           0
# grade                                 0
# sub_grade                             0
# emp_title                          2459
# emp_length                         1075
# home_ownership                        0
# annual_inc                            0
# verification_status                   0
# issue_d                               0
# loan_status                           0
# pymnt_plan                            0
# url                                   0
# desc                              12940
# purpose                               0
# title                                11
# zip_code                              0
# ...

# %%
# percentsge of missing values

# loan_df.isnull().sum()/len(loan_df)*100

# %%
no_val = round((loan_df.isnull().sum()/len(loan_df)*100), 2)
no_val.loc[no_val > 0]
# Out:
# emp_title                           6.19
# emp_length                          2.71
# desc                               32.58
# title                               0.03
# mths_since_last_delinq             64.66
# mths_since_last_record             92.99
# revol_util                          0.13
# last_pymnt_d                        0.18
# next_pymnt_d                       97.13
# last_credit_pull_d                  0.01
# collections_12_mths_ex_med          0.14
# mths_since_last_major_derog       100.00
# annual_inc_joint                  100.00
# dti_joint                         100.00
# verification_status_joint         100.00
# tot_coll_amt                      100.00
# tot_cur_bal                       100.00
# open_acc_6m                       100.00
# open_il_6m                        100.00
# open_il_12m                       100.00
# open_il_24m                       100.00
# mths_since_rcnt_il                100.00
# total_bal_il                      100.00
# ...

# %%
# Removing null values

missing_column_values = list(no_val[no_val >= 60]. index)
len(missing_column_values)
# Out:
# 57

# %% [markdown]
# From the above csv file, wec an conclude that more than 50 percentage of values were null/missing
# in the 57 columns. It means out of 111 columns we can rule out more than 50 columns.

# %%
# After dropping the missing values

loan_df = pd.read_csv('loan.csv')
loan_df = loan_df.drop(missing_column_values, axis=1) # representing the columns as axis = 1 in dataframe
loan_df.shape
# Out:
# (39717, 54)

# %%
loan_df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code', 'application_type', 'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens'], dtype='object')

# %% [markdown]
# Univariate analysis and Bi-variate analysis

# %%
loan_df = pd.read_csv('loan.csv')
loan_df = loan_df.drop(['emp_title', \
                        'desc', \
                        'id', \
                        'title', \
                        'initial_list_status', \
                        'url'], \
                       axis=1)

# %%
loan_df.drop(['member_id'], axis = 1, inplace = True)

# %%
loan_df.head(10)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade emp_length home_ownership  annual_inc verification_status issue_d  loan_status pymnt_plan             purpose zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code application_type  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  \
# ...

# %%
loan_df.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv   installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  mths_since_last_delinq  mths_since_last_record      open_acc       pub_rec      revol_bal     total_acc     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq 
# ...

# %%
# After observing the data by removing few columns, which are irrelevant, still few columns like delinq_2yrs, 
#collections_12_mths_ex_med, tax_alients etc are mostly the columns values are zero

# %%
loan_df.drop(['delinq_amnt', 'acc_now_delinq', 'collections_12_mths_ex_med', 'policy_code', 'pymnt_plan'], axis = 1, inplace = True)

# %%
loan_df.drop(['chargeoff_within_12_mths', 'tax_liens'], axis = 1, inplace = True)

# %%
loan_df.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv   installment    annual_inc           dti   delinq_2yrs  inq_last_6mths  mths_since_last_delinq  mths_since_last_record      open_acc       pub_rec      revol_bal     total_acc     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee  last_pymnt_amnt  mths_since_last_major_derog  annual_inc_joint  dti_joint  verification_status_joint  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# ...

# %%
# plot according to the category-wise, So that we can findout the purpose for taking the loan and the fintech companies
# able to get a conclution whether they want to loan or not by legit purpose.

plt.figure(figsize=(10, 5))
plt.xticks(rotation=50)
y = sns.countplot(x = 'purpose', data = loan_df, order = loan_df['purpose'].value_counts().index)

# %% [markdown]
# By the above plot we can say that majority of the purpose is for debt consolidfation
# and least is on renewable_energy.

# %% [markdown]
# -> Lets focus on the first top five 1. Debt_consolidated, 2. credit_ard, 3. other, 4. home_improvemnt and major purchases and also need to focus on and also need to observe how much amount the customer is asking and amount invested by the invester and the lender.
#
# -> Based on that we can estimate how much percentage of customers are expecting loan of bigger amount or smaller amount

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,3,1)
sns.boxplot(loan_df['loan_amnt'], color = 'black')
plt.title("Loan amnt applied by theCustomer")
plt.subplot(1,3,2)
sns.boxplot(loan_df['funded_amnt'], color = 'blue')
plt.title("Amount given by the lender")
plt.subplot(1,3,3)
sns.boxplot(data=loan_df['funded_amnt_inv'], color = 'red')
plt.title("Invested by the Investor")
plt.tight_layout()

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,3,1)
sns.boxplot(data=loan_df, x = 'loan_amnt', orient = 'v')
plt.title("aLoan amnt applied by theCustomer")
plt.subplot(1,3,2)
sns.boxplot(data=loan_df, x = 'funded_amnt', orient = 'v')
plt.title("aAmount given by the lender")
plt.subplot(1,3,3)
sns.boxplot(data=loan_df, x = 'funded_amnt_inv', orient = 'v')
plt.title("Invested by the Investor")
# Out:
# Text(0.5,1,'Invested by the Investor')

# %% [markdown]
# Note : We can conclude that most of the the customers applied for a loan for small amounts
#         i.e., minimum amount 5000 to maximum_amount 15000

# %%
#Need to check how many loans issued by the company according to the year wise. sometimes issuing the loans to
#the customer is also depends on the fintech company target and at the same time depends on that company growth
#as well.

plt.figure(figsize = (40, 20))
#sns.countplot(loan_df['month'])
sns.countplot(loan_df['issue_d'])
#plt.title("Loan applications issued month wise")
plt.show()

# %% [markdown]
# Note :As per the plot, December-11 month received most of the loans.

# %%
# Checking the interest rate and status of the loan
loan_df['int_rate']
# Out:
# 0        10.65%
# 1        15.27%
# 2        15.96%
# 3        13.49%
# 4        12.69%
# 5         7.90%
# 6        15.96%
# 7        18.64%
# 8        21.28%
# 9        12.69%
# 10       14.65%
# 11       12.69%
# 12       13.49%
# 13        9.91%
# 14       10.65%
# 15       16.29%
# 16       15.27%
# 17        6.03%
# 18       11.71%
# 19        6.03%
# 20       15.27%
# 21       12.42%
# 22       11.71%
# 23       11.71%
# 24       11.71%
# 25        9.91%
# 26       14.27%
# 27       16.77%
# 28       11.71%
# 29       11.71%
# 30        7.51%
# 31        7.90%
# 32       15.96%
# 33        8.90%
# 34       15.96%
# 35       10.65%
# 36        9.91%
# 37        7.90%
# 38       12.42%
# 39       12.69%
# 40        7.51%
# 41        7.90%
# 42       18.25%
# 43       16.77%
# 44        6.03%
# 45        9.91%
# 46        8.90%
# 47       10.65%
# 48        6.03%
# 49        6.62%
# 50        9.91%
# 51        9.91%
# 52       10.65%
# 53       15.96%
# 54        9.91%
# ...

# %%
plt.figure(figsize = (10,3))
sns.countplot(data = loan_df, x = 'term', color = 'blue')
plt.title("Months to be paid")
plt.tight_layout()

# %% [markdown]
# From the above observation most of the loans were 36 months or 60 months, if we compare 36 monthsloans are more.
# we need to consider fewthings how come they decide short term or long term.

# %% [markdown]
# #Interest rate and loan status. Need to check how many customers are repaying the loan and defaulters.

# %%
loan_df['int_rate'].describe()
# Out:
# count      39717
# unique       371
# top       10.99%
# freq         956
# Name: int_rate, dtype: object

# %%
plt.figure(figsize=(30, 10))
palette = ['#800000', '#000000']
plt.subplot(221)
a = sns.countplot(x = 'interest_payment', data = loan_df, palette=palette)
plt.title('Loan_status Interst rate')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-271-3c0f0444167b> in <module>()
#       2 palette = ['#800000', '#000000']
#       3 plt.subplot(221)
# ----> 4 a = sns.countplot(x = 'interest_payment', data = loan_df, palette=palette)
#       5 plt.title('Loan_status Interst rate')
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3357                           estimator, ci, n_boot, units,
#    3358                           orient, color, palette, saturation,
# -> 3359                           errcolor, errwidth, capsize, dodge)
#    3360
#    3361     plotter.value_label = "count"
#
# ...

# %%
pltDistBar(loan_df,'annual_inc', 'annual_inc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-272-a6cac76f4582> in <module>()
# ----> 1 pltDistBar(loan_df,'annual_inc', 'annual_inc')
#
# NameError: name 'pltDistBar' is not defined

# %%
sns.distplot(loan_df['annual_inc'], color = 'red', bins = 30)

# %%
loan_df['annual_inc'].describe()
# Out:
# count    3.971700e+04
# mean     6.896893e+04
# std      6.379377e+04
# min      4.000000e+03
# 25%      4.040400e+04
# 50%      5.900000e+04
# 75%      8.230000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
# from the above analysis we know that Home and mortage loans are more compare to others

loan_df['home_ownership'].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER', 'NONE'], dtype=object)

# %%
plt.figure(figsize = (15, 5))
x= sns.countplot(loan_df['home_ownership'])
plt.title('home loan applications')
plt.show()

# %% [markdown]
# Note : The customers who are living in rented house were received high number of applications

# %% [markdown]
# if we compare with loan_status and home_ownership, the term 60 months customers are charged_off

# %%
plt.figure(figsize = (13, 5))
sns.distplot(loan_df['installment'], color = 'green')
plt.title("Inst_Distribution_plot")
plt.show()

# %%
loan_df['int_rate'].describe()
ranges = [0, 10, 20, 30]
labels = ['0-10', '10-20', '20-30']
loan_df['int_rate'] = pd.cut(loan_df['int_rate'], ranges, labels = labels)

# %%
# Home owner and Loan amount distribution

plt.figure(figsize=(15, 5))
sns.boxplot(x = 'home_ownership', y= 'loan_amnt', data = loan_df)
plt.title("Home owner and Loan amount distribution")
plt.show()

# %% [markdown]
# By observation we can say mortage was the high compare to other spread.

# %%
# delinq_2yrs
loan_df['delinq_2yrs']. unique()
# Out:
# array([ 0,  2,  3,  1,  4,  6,  5,  8,  7,  9, 11])

# %%
pd.crosstab(loan_df['delinq_2yrs'], loan_df['loan_status'])
# Out:
# loan_status  Charged Off  Current  Fully Paid
# delinq_2yrs
# 0                   4936     1019       29450
# 1                    507       96        2700
# 2                    130       14         543
# 3                     35        8         177
# 4                     13        2          47
# 5                      3        1          18
# 6                      1        0           9
# 7                      1        0           3
# 8                      1        0           1
# 9                      0        0           1
# 11                     0        0           1

# %%
loan_df['loan_status']
# Out:
# 0         Fully Paid
# 1        Charged Off
# 2         Fully Paid
# 3         Fully Paid
# 4            Current
# 5         Fully Paid
# 6         Fully Paid
# 7         Fully Paid
# 8        Charged Off
# 9        Charged Off
# 10        Fully Paid
# 11        Fully Paid
# 12       Charged Off
# 13        Fully Paid
# 14       Charged Off
# 15        Fully Paid
# 16        Fully Paid
# 17        Fully Paid
# 18        Fully Paid
# 19        Fully Paid
# 20        Fully Paid
# 21       Charged Off
# 22        Fully Paid
# 23        Fully Paid
# 24       Charged Off
# 25        Fully Paid
# 26       Charged Off
# 27       Charged Off
# 28        Fully Paid
# 29        Fully Paid
# 30        Fully Paid
# 31        Fully Paid
# 32           Current
# 33        Fully Paid
# 34        Fully Paid
# 35        Fully Paid
# 36        Fully Paid
# 37        Fully Paid
# 38        Fully Paid
# 39           Current
# 40        Fully Paid
# 41        Fully Paid
# 42        Fully Paid
# ...

# %%
from sklearn.preprocessing import LabelEncoder
la= LabelEncoder()
loan_df['loan_status'] = la.fit_transform(loan_df['loan_status'])

# %%
loan_df.drop(['out_prncp', "out_prncp_inv"], axis = 1, inplace = True)

# %%
#correlation between Variables

# %%
corr = loan_df.corr()
corr
# Out:
#                                       id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  installment  annual_inc  loan_status       dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc   pub_rec  revol_bal  total_acc  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  mths_since_recent_bc_dlq 
# ...

# %% [markdown]
# Most of the loans were more than 30 days past-due incidences of delinquency in the borrower's credit file
# for the past 2 years

# %%
plt.figure(figsize = (100, 80))
sns.heatmap(corr, annot=True, linewidth=.5, cmap ="YlGnBu")
plt.show()

# %%
Observations
-------------
1. from the above plots, we can say that interest rate increases, chances for applicants choose to default the loan.
but that is for business. But Mortage loans there is a guarantee of money comes back.
2. Even if the customer can't pay the moneyback, with the help of mortage we can able to recover.
3. The loan will not be defaulted if the principle amount is received on the date.
4. we observed that 36 month term loans are high.
